# %% [markdown]
# # Assignment #10 - Data Gathering and Warehousing - DSSA-5102
#
# Instructor: Melissa Laurino</br>
# Spring 2024</br>
#
# Name: Louise Ramos
# </br>
# Date: 04/14/2023
# <br>
# <br>
# **At this time in the semester:** <br>
# --We have explored a dataset. <br>
# --We have cleaned our dataset. <br>
# --We created a Github account with a repository for this class and included a Metadata file about our data. <br>
# --We introduced general and more advanced SQL syntax, queries, and applications in R.<br>
# --Created our own database from scratch in R using libraries RMariaDB and RSQLite <br>
# --Populated our databases we created from scratch<br>
# --Created a visual enhanced entity relationship diagram for our database
# <br>
#
# **Objective**: Connect to a website using an API. Gather live data from a website using an API.<br>
# **If you would like to connect to a different social media platform that you use instead of INaturalist, that is totally fine as long as you comment/explain your thought process!**<br>
# <br>
# **iNaturalist**: iNaturalist is a community of citizen scientists that encourages accurate data collection and species identification of the natural world.
# <br>
# No observations of captive plants or animals should be included in the iNaturalist data. Research grade observations have been verified by the community in terms of species ID, location, etc. Research grade observations have been verified by the community of experts in that field.
# <br>
# API's are useful to bridge the gap between manually querying and downloading data, and then uploading them into R/Python, by just working with the live data directly in your platform of choice.
#
# Follow the instructions below to complete the assignment. Answer any questions in markdown cell boxes. Be sure to comment all code.

# %% [markdown]
# Learn more about the iNaturalist API: https://api.inaturalist.org/v1/docs/#!/Observations/get_observations_observers<br><br>
#
# R packages for working with iNaturalist API to gather live data:<br>
# spocc: https://cran.r-project.org/web/packages/spocc/spocc.pdf <br>
# rinat: https://cran.r-project.org/web/packages/rinat/rinat.pdf

# %%
# Importing required libraries
import requests
import json

# %% [markdown]
# ## Accessing iNaturalist data via API from scratch:
#
# ***Obtaining an iNaturalist API token:***<br>
# Create a username and password and **log in** to www.inaturalist.org using those credentials.<br>
# In the same browser, obtain your INaturalist API Token by using this link: https://www.inaturalist.org/users/api_token<br>
# Do not click this link more than once or it will regenerate your token!<br>
# With iNaturalist, this token is <b>ONLY<b> valid for 24hrs.

# %%
#Enter your generated API token here:
token = "eyJhbGciOiJIUzUxMiJ9.eyJ1c2VyX2lkIjo3OTc4MzMzLCJleHAiOjE3MTMyMjAxNTV9.CdXg7E_cqCXXSppGUOTbPue5BLcDX90_V-Zn1bj1zY99JVbhMfL-i8CDxX5x_s97mdo1pxhVp71DHmTSwvlg-w"

#Define the iNaturalist API endpoint. This is defined by www.inaturalist.org.
base_url = "https://api.inaturalist.org/v1"

# %%
# Fetch the currently logged in user using the requests library
user_url = "/users/me"

request_url = base_url + user_url

# Make sure to include token for authorization
headers = {
    "Authorization": f"{token}"
}

# Make request to inaturalist api
response = requests.get(request_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    user_data = response.json()
    
    # Format the print for the json
    print(json.dumps(user_data, indent=1))
else:
    # Print an error message if not successful
    print("Error:", response.status_code)
# Out:
# {
#  "total_results": 1,
#  "page": 1,
#  "per_page": 1,
#  "results": [
#   {
#    "id": 7978333,
#    "login": "lnramos",
#    "spam": false,
#    "suspended": false,
#    "created_at": "2024-04-14T22:28:45+00:00",
#    "login_autocomplete": "lnramos",
#    "login_exact": "lnramos",
#    "name": null,
#    "name_autocomplete": null,
#    "orcid": null,
#    "icon": null,
#    "observations_count": 0,
#    "identifications_count": 0,
#    "journal_posts_count": 0,
#    "activity_count": 0,
#    "species_count": 0,
#    "universal_search_rank": 0,
#    "roles": [],
#    "site_id": 1,
#    "updated_at": "2024-04-14T22:28:45+00:00",
#    "description": null,
#    "search_place_id": null,
#    "confirmed_at": null,
#    "confirmation_sent_at": "2024-04-14T22:28:45+00:00",
#    "time_zone": "Pacific Time (US & Canada)",
#    "email": "nramos54@yahoo.com",
#    "unconfirmed_email": null,
#    "locale": "en-US",
#    "place_id": null,
#    "pi_consent": true,
#    "data_transfer_consent": true,
#    "prefers_automatic_taxonomic_changes": true,
#    "prefers_comment_email_notification": true,
#    "prefers_common_names": true,
#    "prefers_community_taxa": true,
#    "prefers_identification_email_notification": true,
#    "prefers_mention_email_notification": true,
#    "prefers_message_email_notification": true,
#    "prefers_monthly_supporter_badge": false,
#    "prefers_no_email": false,
#    "prefers_no_tracking": false,
#    "preferred_observation_fields_by": "anyone",
#    "preferred_observation_license": "CC-BY-NC",
#    "preferred_photo_license": "CC-BY-NC",
#    "prefers_project_added_your_observation_email_notification": true,
#    "preferred_project_addition_by": "any",
#    "prefers_project_curator_change_email_notification": true,
#    "prefers_project_journal_post_email_notification": true,
#    "prefers_receive_mentions": true,
#    "prefers_redundant_identification_notifications": true,
#    "prefers_scientific_name_first": false,
#    "preferred_sound_license": "CC-BY-NC",
#    "prefers_taxon_change_email_notification": true,
#    "prefers_taxon_or_place_observation_email_notification": true,
#    "prefers_user_observation_email_notification": true,
#    "muted_user_ids": [],
#    "blocked_user_ids": [],
#    "privileges": [],
#    "monthly_supporter": false,
#    "taxon_name_priorities": [],
#    "site": {
#     "id": 1,
#     "name": "iNaturalist",
#     "url": "https://www.inaturalist.org",
#     "place_id": null,
#     "locale": null,
#     "site_name_short": "iNat",
#     "icon_url": "https://static.inaturalist.org/sites/1-logo_square.png"
#    },
#    "icon_url": null
#   }
#  ]
# }

# %%
# Request for observations near Stockton using the v1/observations api
obs_url = "/observations"
obs_request_url = base_url + obs_url

# Define parameters for the request
parameters = {
    "lat": 39.4930,
    "lng": 74.5338,
    "radius": 50, # Radius around lat/lng in km
    "per_page": 10  # Number of results per page
}

# Make the GET request to the API
response = requests.get(obs_request_url, params=parameters)

#Print the response to ensure you are connected:

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    obs_data = response.json()
    
    # Format the print for the json
    print(json.dumps(obs_data, indent=1))
else:
    # Print an error message if not successful
    print("Error:", response.status_code)
# Out:
# {
#  "total_results": 4,
#  "page": 1,
#  "per_page": 10,
#  "results": [
#   {
#    "quality_grade": "casual",
#    "time_observed_at": "2023-09-20T10:09:45+06:00",
#    "taxon_geoprivacy": null,
#    "annotations": [],
#    "uuid": "feed8fa3-ae4f-45ac-96ff-0ac078df5ec8",
#    "observed_on_details": {
#     "date": "2023-09-20",
#     "day": 20,
#     "month": 9,
#     "year": 2023,
#     "hour": 10,
#     "week": 38
#    },
#    "id": 184084821,
#    "cached_votes_total": 0,
#    "identifications_most_agree": true,
#    "created_at_details": {
#     "date": "2023-09-20",
#     "day": 20,
#     "month": 9,
#     "year": 2023,
#     "hour": 12,
#     "week": 38
#    },
#    "species_guess": "Tropical Leatherleaf Slug",
#    "identifications_most_disagree": false,
#    "tags": [],
#    "positional_accuracy": 1982403,
#    "comments_count": 0,
#    "site_id": 1,
#    "created_time_zone": "Asia/Urumqi",
#    "license_code": "cc-by-nc",
#    "observed_time_zone": "Asia/Urumqi",
#    "quality_metrics": [
#     {
#      "id": 13844011,
#      "user_id": 1208365,
#      "metric": "location",
#      "agree": false,
#      "user": {
#       "id": 1208365,
#       "login": "kevin474",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2018-09-14T14:01:01+00:00",
#       "login_autocomplete": "kevin474",
#       "login_exact": "kevin474",
#       "name": "Kevin Huang",
#       "name_autocomplete": "Kevin Huang",
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/1208365/thumb.jpg?1586627577",
#       "observations_count": 185,
#       "identifications_count": 142527,
#       "journal_posts_count": 0,
#       "activity_count": 142712,
#       "species_count": 52,
#       "universal_search_rank": 185,
#       "roles": [],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/1208365/medium.jpg?1586627577"
#      }
#     }
#    ],
#    "public_positional_accuracy": 1982403,
#    "reviewed_by": [
#     103144,
#     601423,
#     1208365
#    ],
#    "oauth_application_id": 3,
#    "flags": [],
#    "created_at": "2023-09-20T12:18:11+06:00",
#    "description": "Amritsar Punjab India",
#    "time_zone_offset": "+06:00",
#    "project_ids_with_curator_id": [],
#    "observed_on": "2023-09-20",
#    "observed_on_string": "2023-09-20 09:39:45+05:30",
#    "updated_at": "2023-09-20T18:29:05+06:00",
#    "sounds": [],
#    "place_ids": [
#     6903,
#     13359,
#     27816,
#     59614,
#     97395
#    ],
#    "captive": false,
#    "taxon": {
#     "is_active": true,
#     "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274/85104/85099",
#     "min_species_ancestry": "48460,1,47115,47114,551391,775797,775800,775812,54927,480274,85104,85099,85102",
#     "endemic": false,
#     "iconic_taxon_id": 47115,
#     "min_species_taxon_id": 85102,
#     "threatened": false,
#     "rank_level": 10,
#     "introduced": true,
#     "native": false,
#     "parent_id": 85099,
#     "name": "Laevicaulis alte",
#     "rank": "species",
#     "extinct": false,
#     "id": 85102,
#     "ancestor_ids": [
#      48460,
#      1,
#      47115,
#      47114,
#      551391,
#      775797,
#      775800,
#      775812,
#      54927,
#      480274,
#      85104,
#      85099,
#      85102
#     ],
#     "created_at": "2011-07-26T03:22:48+00:00",
#     "default_photo": {
#      "id": 35581790,
#      "license_code": "cc-by-nc-nd",
#      "attribution": "(c) MSOne, some rights reserved (CC BY-NC-ND), uploaded by MSOne",
#      "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/35581790/square.jpg",
#      "original_dimensions": {
#       "height": 1600,
#       "width": 2000
#      },
#      "flags": [],
#      "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/35581790/square.jpg",
#      "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/35581790/medium.jpg"
#     },
#     "taxon_changes_count": 3,
#     "taxon_schemes_count": 2,
#     "observations_count": 4601,
#     "photos_locked": false,
#     "universal_search_rank": 4601,
#     "flag_counts": {
#      "resolved": 1,
#      "unresolved": 0
#     },
#     "current_synonymous_taxon_ids": null,
#     "atlas_id": 19082,
#     "complete_species_count": null,
#     "wikipedia_url": "http://en.wikipedia.org/wiki/Tropical_leatherleaf",
#     "iconic_taxon_name": "Mollusca",
#     "preferred_common_name": "Tropical Leatherleaf Slug"
#    },
#    "ident_taxon_ids": [
#     48460,
#     1,
#     47115,
#     47114,
#     551391,
#     775797,
#     775800,
#     775812,
#     54927,
#     480274,
#     85104,
#     85099,
#     85102
#    ],
#    "outlinks": [],
#    "faves_count": 0,
#    "ofvs": [],
#    "num_identification_agreements": 2,
#    "preferences": {
#     "prefers_community_taxon": null
#    },
#    "comments": [],
#    "map_scale": null,
#    "uri": "https://www.inaturalist.org/observations/184084821",
#    "project_ids": [],
#    "community_taxon_id": 85102,
#    "geojson": {
#     "type": "Point",
#     "coordinates": [
#      74.8476138538,
#      39.8667537882
#     ]
#    },
#    "owners_identification_from_vision": true,
#    "identifications_count": 2,
#    "obscured": false,
#    "num_identification_disagreements": 0,
#    "geoprivacy": null,
#    "location": "39.8667537882,74.8476138538",
#    "votes": [],
#    "spam": false,
#    "user": {
#     "id": 103144,
#     "login": "bsbhatti",
#     "spam": false,
#     "suspended": false,
#     "created_at": "2015-05-22T12:59:22+00:00",
#     "site_id": 1,
#     "login_autocomplete": "bsbhatti",
#     "login_exact": "bsbhatti",
#     "name": null,
#     "name_autocomplete": null,
#     "orcid": null,
#     "icon": "https://static.inaturalist.org/attachments/users/icons/103144/thumb.jpg?1683000789",
#     "observations_count": 25,
#     "identifications_count": 0,
#     "journal_posts_count": 0,
#     "activity_count": 25,
#     "species_count": 17,
#     "universal_search_rank": 25,
#     "roles": [],
#     "icon_url": "https://static.inaturalist.org/attachments/users/icons/103144/medium.jpg?1683000789",
#     "preferences": {}
#    },
#    "mappable": false,
#    "identifications_some_agree": true,
#    "project_ids_without_curator_id": [],
#    "place_guess": "Kizilsu, Xinjiang, CN",
#    "identifications": [
#     {
#      "id": 409895316,
#      "uuid": "09b75d07-de9b-44b0-a801-8203083deaad",
#      "user": {
#       "id": 103144,
#       "login": "bsbhatti",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2015-05-22T12:59:22+00:00",
#       "login_autocomplete": "bsbhatti",
#       "login_exact": "bsbhatti",
#       "name": null,
#       "name_autocomplete": null,
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/103144/thumb.jpg?1683000789",
#       "observations_count": 25,
#       "identifications_count": 0,
#       "journal_posts_count": 0,
#       "activity_count": 25,
#       "species_count": 17,
#       "universal_search_rank": 25,
#       "roles": [],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/103144/medium.jpg?1683000789"
#      },
#      "created_at": "2023-09-20T14:18:11+08:00",
#      "created_at_details": {
#       "date": "2023-09-20",
#       "day": 20,
#       "month": 9,
#       "year": 2023,
#       "hour": 14,
#       "week": 38
#      },
#      "body": null,
#      "category": "improving",
#      "current": true,
#      "flags": [],
#      "own_observation": true,
#      "taxon_change": null,
#      "vision": true,
#      "disagreement": null,
#      "previous_observation_taxon_id": 85099,
#      "spam": false,
#      "taxon_id": 85099,
#      "hidden": false,
#      "moderator_actions": [],
#      "taxon": {
#       "id": 85099,
#       "rank": "genus",
#       "rank_level": 20,
#       "iconic_taxon_id": 47115,
#       "ancestor_ids": [
#        48460,
#        1,
#        47115,
#        47114,
#        551391,
#        775797,
#        775800,
#        775812,
#        54927,
#        480274,
#        85104
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 85099,
#       "name": "Laevicaulis",
#       "parent_id": 85104,
#       "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274/85104",
#       "min_species_ancestry": "48460,1,47115,47114,551391,775797,775800,775812,54927,480274,85104,85099",
#       "extinct": false,
#       "created_at": "2011-07-26T03:22:47+00:00",
#       "default_photo": {
#        "id": 56437999,
#        "license_code": "cc-by",
#        "attribution": "(c) suncana, some rights reserved (CC BY), uploaded by suncana",
#        "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#        "original_dimensions": {
#         "height": 1365,
#         "width": 2048
#        },
#        "flags": [],
#        "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#        "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 1,
#       "observations_count": 5539,
#       "photos_locked": false,
#       "universal_search_rank": 5539,
#       "flag_counts": {
#        "resolved": 0,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Laevicaulis",
#       "iconic_taxon_name": "Mollusca",
#       "ancestors": [
#        {
#         "id": 1,
#         "rank": "kingdom",
#         "rank_level": 70,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1
#         ],
#         "is_active": true,
#         "name": "Animalia",
#         "parent_id": 48460,
#         "ancestry": "48460",
#         "extinct": false,
#         "default_photo": {
#          "id": 80678745,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/medium.jpg"
#         },
#         "taxon_changes_count": 8,
#         "taxon_schemes_count": 2,
#         "observations_count": 99938667,
#         "flag_counts": {
#          "resolved": 15,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Animal",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Animals"
#        },
#        {
#         "id": 47115,
#         "rank": "phylum",
#         "rank_level": 60,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115
#         ],
#         "is_active": true,
#         "name": "Mollusca",
#         "parent_id": 1,
#         "ancestry": "48460/1",
#         "extinct": false,
#         "default_photo": {
#          "id": 58051104,
#          "license_code": null,
#          "attribution": "(c) Ian Shaw, all rights reserved, uploaded by Ian Shaw",
#          "url": "https://static.inaturalist.org/photos/58051104/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1800
#          },
#          "flags": [],
#          "square_url": "https://static.inaturalist.org/photos/58051104/square.jpg",
#          "medium_url": "https://static.inaturalist.org/photos/58051104/medium.jpg"
#         },
#         "taxon_changes_count": 2,
#         "taxon_schemes_count": 2,
#         "observations_count": 2847990,
#         "flag_counts": {
#          "resolved": 5,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Mollusca",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Molluscs"
#        },
#        {
#         "id": 47114,
#         "rank": "class",
#         "rank_level": 50,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114
#         ],
#         "is_active": true,
#         "name": "Gastropoda",
#         "parent_id": 47115,
#         "ancestry": "48460/1/47115",
#         "extinct": false,
#         "default_photo": {
#          "id": 15443371,
#          "license_code": "cc-by-nc-sa",
#          "attribution": "(c) Nicolas Zwahlen, some rights reserved (CC BY-NC-SA), uploaded by Nicolas Zwahlen",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/15443371/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1800
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/15443371/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/15443371/medium.jpg"
#         },
#         "taxon_changes_count": 3,
#         "taxon_schemes_count": 2,
#         "observations_count": 2247827,
#         "flag_counts": {
#          "resolved": 2,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Gastropoda",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Gastropods"
#        },
#        {
#         "id": 551391,
#         "rank": "subclass",
#         "rank_level": 47,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391
#         ],
#         "is_active": true,
#         "name": "Heterobranchia",
#         "parent_id": 47114,
#         "ancestry": "48460/1/47115/47114",
#         "extinct": false,
#         "default_photo": {
#          "id": 30359377,
#          "license_code": null,
#          "attribution": "(c) Shigeru Harazaki, all rights reserved, uploaded by Shigeru Harazaki",
#          "url": "https://static.inaturalist.org/photos/30359377/square.jpg",
#          "original_dimensions": {
#           "height": 950,
#           "width": 633
#          },
#          "flags": [],
#          "square_url": "https://static.inaturalist.org/photos/30359377/square.jpg",
#          "medium_url": "https://static.inaturalist.org/photos/30359377/medium.jpg"
#         },
#         "taxon_changes_count": 4,
#         "taxon_schemes_count": 0,
#         "observations_count": 1547452,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Heterobranchia",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Heterobranchs"
#        },
#        {
#         "id": 775797,
#         "rank": "infraclass",
#         "rank_level": 45,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797
#         ],
#         "is_active": true,
#         "name": "Euthyneura",
#         "parent_id": 551391,
#         "ancestry": "48460/1/47115/47114/551391",
#         "extinct": false,
#         "default_photo": {
#          "id": 24349793,
#          "license_code": "cc-by-nc-sa",
#          "attribution": "(c) Dendroica cerulea, some rights reserved (CC BY-NC-SA)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/24349793/square.jpg",
#          "original_dimensions": {
#           "height": 1000,
#           "width": 1200
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/24349793/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/24349793/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 1545326,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Euthyneura",
#         "iconic_taxon_name": "Mollusca"
#        },
#        {
#         "id": 775800,
#         "rank": "subterclass",
#         "rank_level": 44,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800
#         ],
#         "is_active": true,
#         "name": "Tectipleura",
#         "parent_id": 775797,
#         "ancestry": "48460/1/47115/47114/551391/775797",
#         "extinct": false,
#         "default_photo": {
#          "id": 63974826,
#          "license_code": "cc-by-sa",
#          "attribution": "(c) Brenden Holland, some rights reserved (CC BY-SA), uploaded by Brenden Holland",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/63974826/square.jpg",
#          "original_dimensions": {
#           "height": 934,
#           "width": 1151
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/63974826/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/63974826/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 1235800,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": null,
#         "iconic_taxon_name": "Mollusca"
#        },
#        {
#         "id": 775812,
#         "rank": "superorder",
#         "rank_level": 43,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812
#         ],
#         "is_active": true,
#         "name": "Eupulmonata",
#         "parent_id": 775800,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800",
#         "extinct": false,
#         "default_photo": {
#          "id": 65355890,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Ganjar Cahyadi, some rights reserved (CC BY-NC), uploaded by Ganjar Cahyadi",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/65355890/square.jpg",
#          "original_dimensions": {
#           "height": 1536,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/65355890/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/65355890/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 1112054,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Eupulmonata",
#         "iconic_taxon_name": "Mollusca"
#        },
#        {
#         "id": 54927,
#         "rank": "order",
#         "rank_level": 40,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927
#         ],
#         "is_active": true,
#         "name": "Systellommatophora",
#         "parent_id": 775812,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812",
#         "extinct": false,
#         "default_photo": {
#          "id": 1847988,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Scott Loarie",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1847988/square.jpg",
#          "original_dimensions": {
#           "height": 1579,
#           "width": 1528
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1847988/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1847988/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 24141,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Systellommatophora",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Systellommatophoran Slugs"
#        },
#        {
#         "id": 480274,
#         "rank": "superfamily",
#         "rank_level": 33,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927,
#          480274
#         ],
#         "is_active": true,
#         "name": "Veronicelloidea",
#         "parent_id": 54927,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927",
#         "extinct": false,
#         "default_photo": {
#          "id": 42114049,
#          "license_code": "cc-by-sa",
#          "attribution": "(c) Diogo Luiz, some rights reserved (CC BY-SA), uploaded by Diogo Luiz",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/42114049/square.jpg",
#          "original_dimensions": {
#           "height": 1536,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/42114049/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/42114049/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 21032,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Veronicelloidea",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Leatherleaf and Prism Slugs"
#        },
#        {
#         "id": 85104,
#         "rank": "family",
#         "rank_level": 30,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927,
#          480274,
#          85104
#         ],
#         "is_active": true,
#         "name": "Veronicellidae",
#         "parent_id": 480274,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274",
#         "extinct": false,
#         "default_photo": {
#          "id": 1553244,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) John Slapcinsky, some rights reserved (CC BY-NC)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1553244/square.jpg",
#          "original_dimensions": {
#           "height": 1536,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1553244/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1553244/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 20362,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Veronicellidae",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Leatherleaf Slugs"
#        }
#       ]
#      },
#      "previous_observation_taxon": {
#       "id": 85099,
#       "rank": "genus",
#       "rank_level": 20,
#       "iconic_taxon_id": 47115,
#       "ancestor_ids": [
#        48460,
#        1,
#        47115,
#        47114,
#        551391,
#        775797,
#        775800,
#        775812,
#        54927,
#        480274,
#        85104,
#        85099
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 85099,
#       "name": "Laevicaulis",
#       "parent_id": 85104,
#       "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274/85104",
#       "min_species_ancestry": "48460,1,47115,47114,551391,775797,775800,775812,54927,480274,85104,85099",
#       "extinct": false,
#       "created_at": "2011-07-26T03:22:47+00:00",
#       "default_photo": {
#        "id": 56437999,
#        "license_code": "cc-by",
#        "attribution": "(c) suncana, some rights reserved (CC BY), uploaded by suncana",
#        "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#        "original_dimensions": {
#         "height": 1365,
#         "width": 2048
#        },
#        "flags": [],
#        "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#        "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 1,
#       "observations_count": 5539,
#       "photos_locked": false,
#       "universal_search_rank": 5539,
#       "flag_counts": {
#        "resolved": 0,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Laevicaulis",
#       "iconic_taxon_name": "Mollusca"
#      }
#     },
#     {
#      "id": 409898333,
#      "uuid": "df2bd2a1-2f9a-42cc-8d51-76bf6f3e3daf",
#      "user": {
#       "id": 601423,
#       "login": "yancai",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2017-08-24T12:49:44+00:00",
#       "login_autocomplete": "yancai",
#       "login_exact": "yancai",
#       "name": "Yan Cai",
#       "name_autocomplete": "Yan Cai",
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/601423/thumb.jpg?1693377731",
#       "observations_count": 3532,
#       "identifications_count": 49435,
#       "journal_posts_count": 0,
#       "activity_count": 52967,
#       "species_count": 821,
#       "universal_search_rank": 3532,
#       "roles": [
#        "curator"
#       ],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/601423/medium.jpg?1693377731"
#      },
#      "created_at": "2023-09-20T14:41:33+08:00",
#      "created_at_details": {
#       "date": "2023-09-20",
#       "day": 20,
#       "month": 9,
#       "year": 2023,
#       "hour": 14,
#       "week": 38
#      },
#      "body": null,
#      "category": "improving",
#      "current": true,
#      "flags": [],
#      "own_observation": false,
#      "taxon_change": null,
#      "vision": false,
#      "disagreement": false,
#      "previous_observation_taxon_id": 85099,
#      "spam": false,
#      "taxon_id": 85102,
#      "hidden": false,
#      "moderator_actions": [],
#      "taxon": {
#       "id": 85102,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 47115,
#       "ancestor_ids": [
#        48460,
#        1,
#        47115,
#        47114,
#        551391,
#        775797,
#        775800,
#        775812,
#        54927,
#        480274,
#        85104,
#        85099
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 85102,
#       "name": "Laevicaulis alte",
#       "parent_id": 85099,
#       "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274/85104/85099",
#       "min_species_ancestry": "48460,1,47115,47114,551391,775797,775800,775812,54927,480274,85104,85099,85102",
#       "extinct": false,
#       "created_at": "2011-07-26T03:22:48+00:00",
#       "default_photo": {
#        "id": 35581790,
#        "license_code": "cc-by-nc-nd",
#        "attribution": "(c) MSOne, some rights reserved (CC BY-NC-ND), uploaded by MSOne",
#        "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/35581790/square.jpg",
#        "original_dimensions": {
#         "height": 1600,
#         "width": 2000
#        },
#        "flags": [],
#        "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/35581790/square.jpg",
#        "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/35581790/medium.jpg"
#       },
#       "taxon_changes_count": 3,
#       "taxon_schemes_count": 2,
#       "observations_count": 4601,
#       "photos_locked": false,
#       "universal_search_rank": 4601,
#       "flag_counts": {
#        "resolved": 1,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": 19082,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Tropical_leatherleaf",
#       "iconic_taxon_name": "Mollusca",
#       "preferred_common_name": "Tropical Leatherleaf Slug",
#       "ancestors": [
#        {
#         "id": 1,
#         "rank": "kingdom",
#         "rank_level": 70,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1
#         ],
#         "is_active": true,
#         "name": "Animalia",
#         "parent_id": 48460,
#         "ancestry": "48460",
#         "extinct": false,
#         "default_photo": {
#          "id": 80678745,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/medium.jpg"
#         },
#         "taxon_changes_count": 8,
#         "taxon_schemes_count": 2,
#         "observations_count": 99938667,
#         "flag_counts": {
#          "resolved": 15,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Animal",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Animals"
#        },
#        {
#         "id": 47115,
#         "rank": "phylum",
#         "rank_level": 60,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115
#         ],
#         "is_active": true,
#         "name": "Mollusca",
#         "parent_id": 1,
#         "ancestry": "48460/1",
#         "extinct": false,
#         "default_photo": {
#          "id": 58051104,
#          "license_code": null,
#          "attribution": "(c) Ian Shaw, all rights reserved, uploaded by Ian Shaw",
#          "url": "https://static.inaturalist.org/photos/58051104/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1800
#          },
#          "flags": [],
#          "square_url": "https://static.inaturalist.org/photos/58051104/square.jpg",
#          "medium_url": "https://static.inaturalist.org/photos/58051104/medium.jpg"
#         },
#         "taxon_changes_count": 2,
#         "taxon_schemes_count": 2,
#         "observations_count": 2847990,
#         "flag_counts": {
#          "resolved": 5,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Mollusca",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Molluscs"
#        },
#        {
#         "id": 47114,
#         "rank": "class",
#         "rank_level": 50,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114
#         ],
#         "is_active": true,
#         "name": "Gastropoda",
#         "parent_id": 47115,
#         "ancestry": "48460/1/47115",
#         "extinct": false,
#         "default_photo": {
#          "id": 15443371,
#          "license_code": "cc-by-nc-sa",
#          "attribution": "(c) Nicolas Zwahlen, some rights reserved (CC BY-NC-SA), uploaded by Nicolas Zwahlen",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/15443371/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1800
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/15443371/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/15443371/medium.jpg"
#         },
#         "taxon_changes_count": 3,
#         "taxon_schemes_count": 2,
#         "observations_count": 2247827,
#         "flag_counts": {
#          "resolved": 2,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Gastropoda",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Gastropods"
#        },
#        {
#         "id": 551391,
#         "rank": "subclass",
#         "rank_level": 47,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391
#         ],
#         "is_active": true,
#         "name": "Heterobranchia",
#         "parent_id": 47114,
#         "ancestry": "48460/1/47115/47114",
#         "extinct": false,
#         "default_photo": {
#          "id": 30359377,
#          "license_code": null,
#          "attribution": "(c) Shigeru Harazaki, all rights reserved, uploaded by Shigeru Harazaki",
#          "url": "https://static.inaturalist.org/photos/30359377/square.jpg",
#          "original_dimensions": {
#           "height": 950,
#           "width": 633
#          },
#          "flags": [],
#          "square_url": "https://static.inaturalist.org/photos/30359377/square.jpg",
#          "medium_url": "https://static.inaturalist.org/photos/30359377/medium.jpg"
#         },
#         "taxon_changes_count": 4,
#         "taxon_schemes_count": 0,
#         "observations_count": 1547452,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Heterobranchia",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Heterobranchs"
#        },
#        {
#         "id": 775797,
#         "rank": "infraclass",
#         "rank_level": 45,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797
#         ],
#         "is_active": true,
#         "name": "Euthyneura",
#         "parent_id": 551391,
#         "ancestry": "48460/1/47115/47114/551391",
#         "extinct": false,
#         "default_photo": {
#          "id": 24349793,
#          "license_code": "cc-by-nc-sa",
#          "attribution": "(c) Dendroica cerulea, some rights reserved (CC BY-NC-SA)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/24349793/square.jpg",
#          "original_dimensions": {
#           "height": 1000,
#           "width": 1200
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/24349793/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/24349793/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 1545326,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Euthyneura",
#         "iconic_taxon_name": "Mollusca"
#        },
#        {
#         "id": 775800,
#         "rank": "subterclass",
#         "rank_level": 44,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800
#         ],
#         "is_active": true,
#         "name": "Tectipleura",
#         "parent_id": 775797,
#         "ancestry": "48460/1/47115/47114/551391/775797",
#         "extinct": false,
#         "default_photo": {
#          "id": 63974826,
#          "license_code": "cc-by-sa",
#          "attribution": "(c) Brenden Holland, some rights reserved (CC BY-SA), uploaded by Brenden Holland",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/63974826/square.jpg",
#          "original_dimensions": {
#           "height": 934,
#           "width": 1151
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/63974826/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/63974826/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 1235800,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": null,
#         "iconic_taxon_name": "Mollusca"
#        },
#        {
#         "id": 775812,
#         "rank": "superorder",
#         "rank_level": 43,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812
#         ],
#         "is_active": true,
#         "name": "Eupulmonata",
#         "parent_id": 775800,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800",
#         "extinct": false,
#         "default_photo": {
#          "id": 65355890,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Ganjar Cahyadi, some rights reserved (CC BY-NC), uploaded by Ganjar Cahyadi",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/65355890/square.jpg",
#          "original_dimensions": {
#           "height": 1536,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/65355890/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/65355890/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 1112054,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Eupulmonata",
#         "iconic_taxon_name": "Mollusca"
#        },
#        {
#         "id": 54927,
#         "rank": "order",
#         "rank_level": 40,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927
#         ],
#         "is_active": true,
#         "name": "Systellommatophora",
#         "parent_id": 775812,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812",
#         "extinct": false,
#         "default_photo": {
#          "id": 1847988,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Scott Loarie",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1847988/square.jpg",
#          "original_dimensions": {
#           "height": 1579,
#           "width": 1528
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1847988/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1847988/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 24141,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Systellommatophora",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Systellommatophoran Slugs"
#        },
#        {
#         "id": 480274,
#         "rank": "superfamily",
#         "rank_level": 33,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927,
#          480274
#         ],
#         "is_active": true,
#         "name": "Veronicelloidea",
#         "parent_id": 54927,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927",
#         "extinct": false,
#         "default_photo": {
#          "id": 42114049,
#          "license_code": "cc-by-sa",
#          "attribution": "(c) Diogo Luiz, some rights reserved (CC BY-SA), uploaded by Diogo Luiz",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/42114049/square.jpg",
#          "original_dimensions": {
#           "height": 1536,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/42114049/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/42114049/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 21032,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Veronicelloidea",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Leatherleaf and Prism Slugs"
#        },
#        {
#         "id": 85104,
#         "rank": "family",
#         "rank_level": 30,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927,
#          480274,
#          85104
#         ],
#         "is_active": true,
#         "name": "Veronicellidae",
#         "parent_id": 480274,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274",
#         "extinct": false,
#         "default_photo": {
#          "id": 1553244,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) John Slapcinsky, some rights reserved (CC BY-NC)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1553244/square.jpg",
#          "original_dimensions": {
#           "height": 1536,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1553244/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/1553244/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 20362,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Veronicellidae",
#         "iconic_taxon_name": "Mollusca",
#         "preferred_common_name": "Leatherleaf Slugs"
#        },
#        {
#         "id": 85099,
#         "rank": "genus",
#         "rank_level": 20,
#         "iconic_taxon_id": 47115,
#         "ancestor_ids": [
#          48460,
#          1,
#          47115,
#          47114,
#          551391,
#          775797,
#          775800,
#          775812,
#          54927,
#          480274,
#          85104,
#          85099
#         ],
#         "is_active": true,
#         "name": "Laevicaulis",
#         "parent_id": 85104,
#         "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274/85104",
#         "extinct": false,
#         "default_photo": {
#          "id": 56437999,
#          "license_code": "cc-by",
#          "attribution": "(c) suncana, some rights reserved (CC BY), uploaded by suncana",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#          "original_dimensions": {
#           "height": 1365,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 5539,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Laevicaulis",
#         "iconic_taxon_name": "Mollusca"
#        }
#       ]
#      },
#      "previous_observation_taxon": {
#       "id": 85099,
#       "rank": "genus",
#       "rank_level": 20,
#       "iconic_taxon_id": 47115,
#       "ancestor_ids": [
#        48460,
#        1,
#        47115,
#        47114,
#        551391,
#        775797,
#        775800,
#        775812,
#        54927,
#        480274,
#        85104,
#        85099
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 85099,
#       "name": "Laevicaulis",
#       "parent_id": 85104,
#       "ancestry": "48460/1/47115/47114/551391/775797/775800/775812/54927/480274/85104",
#       "min_species_ancestry": "48460,1,47115,47114,551391,775797,775800,775812,54927,480274,85104,85099",
#       "extinct": false,
#       "created_at": "2011-07-26T03:22:47+00:00",
#       "default_photo": {
#        "id": 56437999,
#        "license_code": "cc-by",
#        "attribution": "(c) suncana, some rights reserved (CC BY), uploaded by suncana",
#        "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#        "original_dimensions": {
#         "height": 1365,
#         "width": 2048
#        },
#        "flags": [],
#        "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/square.jpg",
#        "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/56437999/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 1,
#       "observations_count": 5539,
#       "photos_locked": false,
#       "universal_search_rank": 5539,
#       "flag_counts": {
#        "resolved": 0,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Laevicaulis",
#       "iconic_taxon_name": "Mollusca"
#      }
#     },
#     {
#      "id": 409954189,
#      "uuid": "6b93913e-082d-4ee5-8c40-42d2ea921d1f",
#      "user": {
#       "id": 1208365,
#       "login": "kevin474",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2018-09-14T14:01:01+00:00",
#       "login_autocomplete": "kevin474",
#       "login_exact": "kevin474",
#       "name": "Kevin Huang",
#       "name_autocomplete": "Kevin Huang",
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/1208365/thumb.jpg?1586627577",
#       "observations_count": 185,
#       "identifications_count": 142527,
#       "journal_posts_count": 0,
#       "activity_count": 142712,
#       "species_count": 52,
#       "universal_search_rank": 185,
#       "roles": [],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/1208365/medium.jpg?1586627577"
#      },
#      "created_at": "2023-09-20T20:29:05+08:00",
#      "created_at_details": {
#       "date": "2023-09-20",
#       "day": 20,
#       "month": 9,
#       "year": 2023,
#       "hour": 20,
#       "week": 38
#      },
#      "body": null,
# ...
#       "activity_count": 84572,
#       "species_count": 2624,
#       "universal_search_rank": 14478,
#       "roles": [
#        "curator"
#       ],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/1065481/medium.jpg?1684566653"
#      },
#      "created_at": "2022-06-14T03:10:32+08:00",
#      "created_at_details": {
#       "date": "2022-06-14",
#       "day": 14,
#       "month": 6,
#       "year": 2022,
#       "hour": 3,
#       "week": 24
#      },
#      "body": "",
#      "category": "leading",
#      "current": true,
#      "flags": [],
#      "own_observation": false,
#      "taxon_change": null,
#      "vision": false,
#      "disagreement": null,
#      "previous_observation_taxon_id": null,
#      "spam": false,
#      "taxon_id": 42044,
#      "hidden": false,
#      "moderator_actions": [],
#      "taxon": {
#       "id": 42044,
#       "rank": "genus",
#       "rank_level": 20,
#       "iconic_taxon_id": 40151,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        40151,
#        848317,
#        848320,
#        848324,
#        41573,
#        42043
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 42044,
#       "name": "Canis",
#       "parent_id": 42043,
#       "ancestry": "48460/1/2/355675/40151/848317/848320/848324/41573/42043",
#       "min_species_ancestry": "48460,1,2,355675,40151,848317,848320,848324,41573,42043,42044",
#       "extinct": false,
#       "created_at": "2008-03-19T00:38:55+00:00",
#       "default_photo": {
#        "id": 13367754,
#        "license_code": "cc-by-nd",
#        "attribution": "(c) Giuseppe Calsamiglia, some rights reserved (CC BY-ND)",
#        "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/13367754/square.jpg",
#        "original_dimensions": {
#         "height": 800,
#         "width": 1200
#        },
#        "flags": [],
#        "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/13367754/square.jpg",
#        "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/13367754/medium.jpg"
#       },
#       "taxon_changes_count": 1,
#       "taxon_schemes_count": 2,
#       "observations_count": 210288,
#       "photos_locked": false,
#       "universal_search_rank": 210288,
#       "flag_counts": {
#        "resolved": 4,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": 8,
#       "wikipedia_url": "https://en.wikipedia.org/wiki/Canis",
#       "complete_rank": "species",
#       "iconic_taxon_name": "Mammalia",
#       "preferred_common_name": "Wolves and Dogs",
#       "ancestors": [
#        {
#         "id": 1,
#         "rank": "kingdom",
#         "rank_level": 70,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1
#         ],
#         "is_active": true,
#         "name": "Animalia",
#         "parent_id": 48460,
#         "ancestry": "48460",
#         "extinct": false,
#         "default_photo": {
#          "id": 80678745,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/medium.jpg"
#         },
#         "taxon_changes_count": 8,
#         "taxon_schemes_count": 2,
#         "observations_count": 99938667,
#         "flag_counts": {
#          "resolved": 15,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Animal",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Animals"
#        },
#        {
#         "id": 2,
#         "rank": "phylum",
#         "rank_level": 60,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2
#         ],
#         "is_active": true,
#         "name": "Chordata",
#         "parent_id": 1,
#         "ancestry": "48460/1",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551845,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 40846458,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 77541,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Chordate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Chordates"
#        },
#        {
#         "id": 355675,
#         "rank": "subphylum",
#         "rank_level": 57,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675
#         ],
#         "is_active": true,
#         "name": "Vertebrata",
#         "parent_id": 2,
#         "ancestry": "48460/1/2",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551642,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 40774163,
#         "flag_counts": {
#          "resolved": 2,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 74422,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Vertebrate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Vertebrates"
#        },
#        {
#         "id": 40151,
#         "rank": "class",
#         "rank_level": 50,
#         "iconic_taxon_id": 40151,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          40151
#         ],
#         "is_active": true,
#         "name": "Mammalia",
#         "parent_id": 355675,
#         "ancestry": "48460/1/2/355675",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551250,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551250/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551250/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551250/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 2,
#         "observations_count": 4550714,
#         "flag_counts": {
#          "resolved": 3,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 6457,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Mammal",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Mammalia",
#         "preferred_common_name": "Mammals"
#        },
#        {
#         "id": 848317,
#         "rank": "subclass",
#         "rank_level": 47,
#         "iconic_taxon_id": 40151,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          40151,
#          848317
#         ],
#         "is_active": true,
#         "name": "Theria",
#         "parent_id": 40151,
#         "ancestry": "48460/1/2/355675/40151",
#         "extinct": false,
#         "default_photo": {
#          "id": 83336879,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/83336879/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/83336879/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/83336879/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 4484471,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 6452,
#         "wikipedia_url": "https://en.wikipedia.org/wiki/Theria",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Mammalia",
#         "preferred_common_name": "Therians"
#        },
#        {
#         "id": 848320,
#         "rank": "infraclass",
#         "rank_level": 45,
#         "iconic_taxon_id": 40151,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          40151,
#          848317,
#          848320
#         ],
#         "is_active": true,
#         "name": "Placentalia",
#         "parent_id": 848317,
#         "ancestry": "48460/1/2/355675/40151/848317",
#         "extinct": false,
#         "default_photo": {
#          "id": 83336736,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/83336736/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/83336736/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/83336736/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 4303243,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 6078,
#         "wikipedia_url": "https://en.wikipedia.org/wiki/Placentalia",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Mammalia",
#         "preferred_common_name": "Placental Mammals"
#        },
#        {
#         "id": 848324,
#         "rank": "superorder",
#         "rank_level": 43,
#         "iconic_taxon_id": 40151,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          40151,
#          848317,
#          848320,
#          848324
#         ],
#         "is_active": true,
#         "name": "Laurasiatheria",
#         "parent_id": 848320,
#         "ancestry": "48460/1/2/355675/40151/848317/848320",
#         "extinct": false,
#         "default_photo": {
#          "id": 30666545,
#          "license_code": "cc-by",
#          "attribution": "(c) Vince Smith, some rights reserved (CC BY)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/30666545/square.jpg",
#          "original_dimensions": {
#           "height": 1152,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/30666545/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/30666545/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 2421923,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 2700,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Laurasiatheria",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Mammalia",
#         "preferred_common_name": "Ungulates, Carnivorans, and Allies"
#        },
#        {
#         "id": 41573,
#         "rank": "order",
#         "rank_level": 40,
#         "iconic_taxon_id": 40151,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          40151,
#          848317,
#          848320,
#          848324,
#          41573
#         ],
#         "is_active": true,
#         "name": "Carnivora",
#         "parent_id": 848324,
#         "ancestry": "48460/1/2/355675/40151/848317/848320/848324",
#         "extinct": false,
#         "default_photo": {
#          "id": 11354784,
#          "license_code": "cc-by",
#          "attribution": "(c) samuelrodgers752, some rights reserved (CC BY)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/11354784/square.jpg",
#          "original_dimensions": {
#           "height": 1365,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/11354784/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/11354784/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 2,
#         "observations_count": 1106519,
#         "flag_counts": {
#          "resolved": 4,
#          "unresolved": 1
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 304,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Carnivora",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Mammalia",
#         "preferred_common_name": "Carnivorans"
#        },
#        {
#         "id": 42043,
#         "rank": "family",
#         "rank_level": 30,
#         "iconic_taxon_id": 40151,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          40151,
#          848317,
#          848320,
#          848324,
#          41573,
#          42043
#         ],
#         "is_active": true,
#         "name": "Canidae",
#         "parent_id": 41573,
#         "ancestry": "48460/1/2/355675/40151/848317/848320/848324/41573",
#         "extinct": false,
#         "default_photo": {
#          "id": 31629587,
#          "license_code": "cc-by",
#          "attribution": "(c) USFWS Endangered Species, some rights reserved (CC BY)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/31629587/square.jpg",
#          "original_dimensions": {
#           "height": 699,
#           "width": 699
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/31629587/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/31629587/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 359617,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 39,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Canidae",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Mammalia",
#         "preferred_common_name": "Canids"
#        }
#       ]
#      }
#     }
#    ]
#   }
#  ]
# }

# %%
# Fetching all examples of eagles in the state of New Jersey

# Declare urls
places_url = "/places/autocomplete"
place_request_url = base_url + places_url

# Define parameters for the request to find New Jersey
parameters_place = {
    "q": "New Jersey"
}

# Make the GET request to the API
response = requests.get(place_request_url, params=parameters_place)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    place_data = response.json()
    # Grab the id for New Jersey
    nj_place_id = place_data["results"][0]["id"]
    print(f"New Jersey id is: {nj_place_id}")


    # Request all information for Bald Eagles in New Jersey
    eagle_params = {
            "taxon_name": "Haliaeetus leucocephalus",  # Taxon name for bald eagles
            "place_id": nj_place_id,
            "per_page": 10  # Number of results per page
        }
    response_observations = requests.get(obs_request_url, params=eagle_params)

    eagle_data = response_observations.json()    
    # Format the print for the json
    print(json.dumps(eagle_data, indent=1))
else:
    # Print an error message if not successful
    print("Error:", response.status_code)
# Out:
# New Jersey id is: 51
# {
#  "total_results": 1914,
#  "page": 1,
#  "per_page": 10,
#  "results": [
#   {
#    "quality_grade": "needs_id",
#    "time_observed_at": "2024-04-14T09:48:51-04:00",
#    "taxon_geoprivacy": null,
#    "annotations": [],
#    "uuid": "f5efb426-abe2-40bd-83e6-9f6870ef9d7f",
#    "observed_on_details": {
#     "date": "2024-04-14",
#     "day": 14,
#     "month": 4,
#     "year": 2024,
#     "hour": 9,
#     "week": 15
#    },
#    "id": 207230966,
#    "cached_votes_total": 0,
#    "identifications_most_agree": false,
#    "created_at_details": {
#     "date": "2024-04-14",
#     "day": 14,
#     "month": 4,
#     "year": 2024,
#     "hour": 14,
#     "week": 15
#    },
#    "species_guess": null,
#    "identifications_most_disagree": false,
#    "tags": [],
#    "positional_accuracy": 20,
#    "comments_count": 0,
#    "site_id": 1,
#    "created_time_zone": "America/New_York",
#    "license_code": "cc-by-nc",
#    "observed_time_zone": "America/New_York",
#    "quality_metrics": [],
#    "public_positional_accuracy": 20,
#    "reviewed_by": [
#     6171703,
#     115129
#    ],
#    "oauth_application_id": 3,
#    "flags": [],
#    "created_at": "2024-04-14T14:57:56-04:00",
#    "description": "",
#    "time_zone_offset": "-05:00",
#    "project_ids_with_curator_id": [],
#    "observed_on": "2024-04-14",
#    "observed_on_string": "2024-04-14 09:48:51-04:00",
#    "updated_at": "2024-04-14T14:58:05-04:00",
#    "sounds": [],
#    "place_ids": [
#     1,
#     51,
#     181,
#     9853,
#     51894,
#     52250,
#     59613,
#     64492,
#     66741,
#     81418,
#     81457,
#     82256,
#     82257,
#     96557,
#     97394,
#     111363,
#     113702,
#     128778,
#     141402,
#     149973,
#     154241
#    ],
#    "captive": false,
#    "taxon": {
#     "is_active": true,
#     "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#     "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#     "endemic": false,
#     "iconic_taxon_id": 3,
#     "min_species_taxon_id": 5305,
#     "threatened": true,
#     "rank_level": 10,
#     "introduced": false,
#     "native": true,
#     "parent_id": 5303,
#     "name": "Haliaeetus leucocephalus",
#     "rank": "species",
#     "extinct": false,
#     "id": 5305,
#     "ancestor_ids": [
#      48460,
#      1,
#      2,
#      355675,
#      3,
#      71261,
#      5067,
#      1542783,
#      5303,
#      5305
#     ],
#     "created_at": "2008-03-13T02:47:51+00:00",
#     "default_photo": {
#      "id": 6149726,
#      "license_code": null,
#      "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#      "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#      "original_dimensions": {
#       "height": 1133,
#       "width": 1440
#      },
#      "flags": [],
#      "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#      "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#     },
#     "taxon_changes_count": 0,
#     "taxon_schemes_count": 10,
#     "observations_count": 136386,
#     "photos_locked": false,
#     "universal_search_rank": 136386,
#     "flag_counts": {
#      "resolved": 5,
#      "unresolved": 0
#     },
#     "current_synonymous_taxon_ids": null,
#     "atlas_id": null,
#     "complete_species_count": null,
#     "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#     "complete_rank": "subspecies",
#     "iconic_taxon_name": "Aves",
#     "preferred_common_name": "Bald Eagle",
#     "conservation_status": {
#      "id": 54335,
#      "place_id": 51,
#      "source_id": 8,
#      "user_id": null,
#      "authority": "NatureServe",
#      "status": "s1b,s1n",
#      "status_name": "critically imperiled",
#      "geoprivacy": null,
#      "iucn": 50
#     }
#    },
#    "ident_taxon_ids": [
#     48460,
#     1,
#     2,
#     355675,
#     3,
#     71261,
#     5067,
#     1542783,
#     5303,
#     5305
#    ],
#    "outlinks": [],
#    "faves_count": 0,
#    "ofvs": [],
#    "num_identification_agreements": 0,
#    "preferences": {
#     "prefers_community_taxon": null
#    },
#    "comments": [],
#    "map_scale": null,
#    "uri": "https://www.inaturalist.org/observations/207230966",
#    "project_ids": [],
#    "community_taxon_id": null,
#    "geojson": {
#     "type": "Point",
#     "coordinates": [
#      -74.5361416667,
#      39.4958000027
#     ]
#    },
#    "owners_identification_from_vision": true,
#    "identifications_count": 0,
#    "obscured": false,
#    "num_identification_disagreements": 0,
#    "geoprivacy": null,
#    "location": "39.4958000027,-74.5361416667",
#    "votes": [],
#    "spam": false,
#    "user": {
#     "id": 6171703,
#     "login": "felisoccidentalis",
#     "spam": false,
#     "suspended": false,
#     "created_at": "2022-09-20T22:24:06+00:00",
#     "site_id": 1,
#     "login_autocomplete": "felisoccidentalis",
#     "login_exact": "felisoccidentalis",
#     "name": null,
#     "name_autocomplete": null,
#     "orcid": null,
#     "icon": "https://static.inaturalist.org/attachments/users/icons/6171703/thumb.jpg?1708735569",
#     "observations_count": 119,
#     "identifications_count": 1,
#     "journal_posts_count": 0,
#     "activity_count": 120,
#     "species_count": 99,
#     "universal_search_rank": 119,
#     "roles": [],
#     "icon_url": "https://static.inaturalist.org/attachments/users/icons/6171703/medium.jpg?1708735569",
#     "preferences": {}
#    },
#    "mappable": true,
#    "identifications_some_agree": false,
#    "project_ids_without_curator_id": [],
#    "place_guess": "Stockton University, Galloway, NJ, US",
#    "identifications": [
#     {
#      "id": 470801245,
#      "uuid": "60a46afa-0804-4149-ba3e-0aea4bcbfebb",
#      "user": {
#       "id": 6171703,
#       "login": "felisoccidentalis",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2022-09-20T22:24:06+00:00",
#       "login_autocomplete": "felisoccidentalis",
#       "login_exact": "felisoccidentalis",
#       "name": null,
#       "name_autocomplete": null,
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/6171703/thumb.jpg?1708735569",
#       "observations_count": 119,
#       "identifications_count": 1,
#       "journal_posts_count": 0,
#       "activity_count": 120,
#       "species_count": 99,
#       "universal_search_rank": 119,
#       "roles": [],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/6171703/medium.jpg?1708735569"
#      },
#      "created_at": "2024-04-14T18:57:56+00:00",
#      "created_at_details": {
#       "date": "2024-04-14",
#       "day": 14,
#       "month": 4,
#       "year": 2024,
#       "hour": 18,
#       "week": 15
#      },
#      "body": null,
#      "category": "leading",
#      "current": true,
#      "flags": [],
#      "own_observation": true,
#      "taxon_change": null,
#      "vision": true,
#      "disagreement": null,
#      "previous_observation_taxon_id": 5305,
#      "spam": false,
#      "taxon_id": 5305,
#      "hidden": false,
#      "moderator_actions": [],
#      "taxon": {
#       "id": 5305,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 3,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        3,
#        71261,
#        5067,
#        1542783,
#        5303
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 5305,
#       "name": "Haliaeetus leucocephalus",
#       "parent_id": 5303,
#       "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#       "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#       "extinct": false,
#       "created_at": "2008-03-13T02:47:51+00:00",
#       "default_photo": {
#        "id": 6149726,
#        "license_code": null,
#        "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#        "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "original_dimensions": {
#         "height": 1133,
#         "width": 1440
#        },
#        "flags": [],
#        "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 10,
#       "observations_count": 136386,
#       "photos_locked": false,
#       "universal_search_rank": 136386,
#       "flag_counts": {
#        "resolved": 5,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#       "complete_rank": "subspecies",
#       "iconic_taxon_name": "Aves",
#       "preferred_common_name": "Bald Eagle",
#       "conservation_status": {
#        "id": 54335,
#        "place_id": 51,
#        "source_id": 8,
#        "user_id": null,
#        "authority": "NatureServe",
#        "status": "s1b,s1n",
#        "status_name": "critically imperiled",
#        "geoprivacy": null,
#        "iucn": 50
#       },
#       "ancestors": [
#        {
#         "id": 1,
#         "rank": "kingdom",
#         "rank_level": 70,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1
#         ],
#         "is_active": true,
#         "name": "Animalia",
#         "parent_id": 48460,
#         "ancestry": "48460",
#         "extinct": false,
#         "default_photo": {
#          "id": 80678745,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/medium.jpg"
#         },
#         "taxon_changes_count": 8,
#         "taxon_schemes_count": 2,
#         "observations_count": 99949886,
#         "flag_counts": {
#          "resolved": 15,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Animal",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Animals"
#        },
#        {
#         "id": 2,
#         "rank": "phylum",
#         "rank_level": 60,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2
#         ],
#         "is_active": true,
#         "name": "Chordata",
#         "parent_id": 1,
#         "ancestry": "48460/1",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551845,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 40846458,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 77541,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Chordate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Chordates"
#        },
#        {
#         "id": 355675,
#         "rank": "subphylum",
#         "rank_level": 57,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675
#         ],
#         "is_active": true,
#         "name": "Vertebrata",
#         "parent_id": 2,
#         "ancestry": "48460/1/2",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551642,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 40774163,
#         "flag_counts": {
#          "resolved": 2,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 74422,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Vertebrate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Vertebrates"
#        },
#        {
#         "id": 3,
#         "rank": "class",
#         "rank_level": 50,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3
#         ],
#         "is_active": true,
#         "name": "Aves",
#         "parent_id": 355675,
#         "ancestry": "48460/1/2/355675",
#         "extinct": false,
#         "default_photo": {
#          "id": 2967053,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Greg Lasley, some rights reserved (CC BY-NC), uploaded by Greg Lasley",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/square.jpg",
#          "original_dimensions": {
#           "height": 1333,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/medium.jpg"
#         },
#         "taxon_changes_count": 4,
#         "taxon_schemes_count": 2,
#         "observations_count": 27376380,
#         "flag_counts": {
#          "resolved": 16,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 10852,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Bird",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Birds"
#        },
#        {
#         "id": 71261,
#         "rank": "order",
#         "rank_level": 40,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261
#         ],
#         "is_active": true,
#         "name": "Accipitriformes",
#         "parent_id": 3,
#         "ancestry": "48460/1/2/355675/3",
#         "extinct": false,
#         "default_photo": {
#          "id": 9972001,
#          "license_code": "cc-by",
#          "attribution": "(c) Jacob Spinks, some rights reserved (CC BY)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1500
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 1463606,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 251,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Accipitriformes",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Hawks, Eagles, Kites, and Allies"
#        },
#        {
#         "id": 5067,
#         "rank": "family",
#         "rank_level": 30,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067
#         ],
#         "is_active": true,
#         "name": "Accipitridae",
#         "parent_id": 71261,
#         "ancestry": "48460/1/2/355675/3/71261",
#         "extinct": false,
#         "default_photo": {
#          "id": 12120585,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) kjohnston406, some rights reserved (CC BY-NC), uploaded by kjohnston406",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/square.jpg",
#          "original_dimensions": {
#           "height": 1417,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 1335826,
#         "flag_counts": {
#          "resolved": 3,
#          "unresolved": 1
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 249,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Accipitridae",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Hawks, Eagles, and Kites"
#        },
#        {
#         "id": 1542783,
#         "rank": "subfamily",
#         "rank_level": 27,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067,
#          1542783
#         ],
#         "is_active": true,
#         "name": "Buteoninae",
#         "parent_id": 5067,
#         "ancestry": "48460/1/2/355675/3/71261/5067",
#         "extinct": false,
#         "default_photo": {
#          "id": 28307358,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Greg Lasley, some rights reserved (CC BY-NC), uploaded by Greg Lasley",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/square.jpg",
#          "original_dimensions": {
#           "height": 1366,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 355699,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 47,
#         "wikipedia_url": null,
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves"
#        },
#        {
#         "id": 5303,
#         "rank": "genus",
#         "rank_level": 20,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067,
#          1542783,
#          5303
#         ],
#         "is_active": true,
#         "name": "Haliaeetus",
#         "parent_id": 1542783,
#         "ancestry": "48460/1/2/355675/3/71261/5067/1542783",
#         "extinct": false,
#         "default_photo": {
#          "id": 45572716,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Carolyn Stewart, some rights reserved (CC BY-NC), uploaded by Carolyn Stewart",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/square.jpg",
#          "original_dimensions": {
#           "height": 1000,
#           "width": 1000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/medium.jpg"
#         },
#         "taxon_changes_count": 2,
#         "taxon_schemes_count": 2,
#         "observations_count": 150894,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": 96883,
#         "complete_species_count": 4,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Sea_eagle",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Northern Sea-Eagles and Fish-Eagles"
#        }
#       ]
#      },
#      "previous_observation_taxon": {
#       "id": 5305,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 3,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        3,
#        71261,
#        5067,
#        1542783,
#        5303,
#        5305
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 5305,
#       "name": "Haliaeetus leucocephalus",
#       "parent_id": 5303,
#       "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#       "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#       "extinct": false,
#       "created_at": "2008-03-13T02:47:51+00:00",
#       "default_photo": {
#        "id": 6149726,
#        "license_code": null,
#        "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#        "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "original_dimensions": {
#         "height": 1133,
#         "width": 1440
#        },
#        "flags": [],
#        "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 10,
#       "observations_count": 136386,
#       "photos_locked": false,
#       "universal_search_rank": 136386,
#       "flag_counts": {
#        "resolved": 5,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#       "complete_rank": "subspecies",
#       "iconic_taxon_name": "Aves",
#       "preferred_common_name": "Bald Eagle",
#       "conservation_status": {
#        "id": 54335,
#        "place_id": 51,
#        "source_id": 8,
#        "user_id": null,
#        "authority": "NatureServe",
#        "status": "s1b,s1n",
#        "status_name": "critically imperiled",
#        "geoprivacy": null,
#        "iucn": 50
#       }
#      }
#     }
#    ],
#    "project_observations": [],
#    "observation_photos": [
#     {
#      "id": 341309545,
#      "position": 0,
#      "uuid": "6843da2a-a5d7-4766-8655-1e6cb95d1a70",
#      "photo_id": 366531635,
#      "photo": {
#       "id": 366531635,
#       "license_code": "cc-by-nc",
#       "original_dimensions": {
#        "width": 640,
#        "height": 640
#       },
#       "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/366531635/square.jpg",
#       "attribution": "(c) felisoccidentalis, some rights reserved (CC BY-NC)",
#       "flags": [],
#       "moderator_actions": [],
#       "hidden": false
#      }
#     },
#     {
#      "id": 341309570,
#      "position": 1,
#      "uuid": "d88e9018-6872-4fff-bc84-fc36fd37c42c",
#      "photo_id": 366531679,
#      "photo": {
#       "id": 366531679,
#       "license_code": "cc-by-nc",
#       "original_dimensions": {
#        "width": 2023,
#        "height": 2023
#       },
#       "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/366531679/square.jpg",
#       "attribution": "(c) felisoccidentalis, some rights reserved (CC BY-NC)",
#       "flags": [],
#       "moderator_actions": [],
#       "hidden": false
#      }
#     }
#    ],
#    "photos": [
#     {
#      "id": 366531635,
#      "license_code": "cc-by-nc",
#      "original_dimensions": {
#       "width": 640,
#       "height": 640
#      },
#      "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/366531635/square.jpg",
#      "attribution": "(c) felisoccidentalis, some rights reserved (CC BY-NC)",
#      "flags": [],
#      "moderator_actions": [],
#      "hidden": false
#     },
#     {
#      "id": 366531679,
#      "license_code": "cc-by-nc",
#      "original_dimensions": {
#       "width": 2023,
#       "height": 2023
#      },
#      "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/366531679/square.jpg",
#      "attribution": "(c) felisoccidentalis, some rights reserved (CC BY-NC)",
#      "flags": [],
#      "moderator_actions": [],
#      "hidden": false
#     }
#    ],
#    "faves": [],
#    "non_owner_ids": []
#   },
#   {
#    "quality_grade": "research",
#    "time_observed_at": "2024-04-14T13:05:00-04:00",
#    "taxon_geoprivacy": null,
#    "annotations": [
#     {
#      "uuid": "77bb41cb-7073-4034-81c4-2431224de91a",
#      "controlled_attribute_id": 17,
#      "controlled_value_id": 18,
#      "concatenated_attr_val": "17|18",
#      "vote_score": 0,
#      "user_id": 1713345,
#      "votes": [],
#      "user": {
#       "id": 1713345,
#       "login": "spaceopossum",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2019-05-03T01:16:12+00:00",
#       "login_autocomplete": "spaceopossum",
#       "login_exact": "spaceopossum",
#       "name": "",
#       "name_autocomplete": "",
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/1713345/thumb.jpeg?1574260056",
#       "observations_count": 975,
#       "identifications_count": 6742,
#       "journal_posts_count": 0,
#       "activity_count": 7717,
#       "species_count": 353,
#       "universal_search_rank": 975,
#       "roles": [],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/1713345/medium.jpeg?1574260056"
#      }
#     },
#     {
#      "uuid": "3d4a3175-2940-46c2-ba7f-4033c5d3d1e3",
#      "controlled_attribute_id": 22,
#      "controlled_value_id": 24,
#      "concatenated_attr_val": "22|24",
#      "vote_score": 0,
#      "user_id": 1713345,
#      "votes": [],
#      "user": {
#       "id": 1713345,
#       "login": "spaceopossum",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2019-05-03T01:16:12+00:00",
#       "login_autocomplete": "spaceopossum",
#       "login_exact": "spaceopossum",
#       "name": "",
#       "name_autocomplete": "",
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/1713345/thumb.jpeg?1574260056",
#       "observations_count": 975,
#       "identifications_count": 6742,
#       "journal_posts_count": 0,
#       "activity_count": 7717,
#       "species_count": 353,
#       "universal_search_rank": 975,
#       "roles": [],
#       "site_id": 1,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/1713345/medium.jpeg?1574260056"
#      }
#     }
#    ],
#    "uuid": "1eed384f-86ff-4be5-8e5a-557e257cf324",
#    "observed_on_details": {
#     "date": "2024-04-14",
#     "day": 14,
#     "month": 4,
#     "year": 2024,
#     "hour": 13,
#     "week": 15
#    },
#    "id": 207206756,
#    "cached_votes_total": 0,
#    "identifications_most_agree": true,
#    "created_at_details": {
#     "date": "2024-04-14",
#     "day": 14,
#     "month": 4,
#     "year": 2024,
#     "hour": 13,
#     "week": 15
#    },
#    "species_guess": "Bald Eagle",
#    "identifications_most_disagree": false,
#    "tags": [],
#    "positional_accuracy": 191,
#    "comments_count": 0,
#    "site_id": 1,
#    "created_time_zone": "America/New_York",
#    "license_code": null,
#    "observed_time_zone": "America/New_York",
#    "quality_metrics": [],
#    "public_positional_accuracy": 191,
#    "reviewed_by": [
#     1587701,
#     1713345,
#     4579164
#    ],
#    "oauth_application_id": null,
#    "flags": [],
#    "created_at": "2024-04-14T13:09:05-04:00",
#    "description": null,
#    "time_zone_offset": "-05:00",
#    "project_ids_with_curator_id": [],
#    "observed_on": "2024-04-14",
#    "observed_on_string": "2024/04/14 1:05 PM",
#    "updated_at": "2024-04-14T18:11:22-04:00",
#    "sounds": [],
#    "place_ids": [
#     1,
#     51,
#     2697,
#     9853,
#     51894,
#     52250,
#     59613,
#     59954,
#     59956,
#     61551,
#     64492,
#     66741,
#     81418,
#     81457,
#     82256,
#     82257,
#     96557,
#     97394,
#     123516,
#     125299,
#     145910,
#     174507,
#     174508
#    ],
#    "captive": false,
#    "taxon": {
#     "is_active": true,
#     "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#     "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#     "endemic": false,
#     "iconic_taxon_id": 3,
#     "min_species_taxon_id": 5305,
#     "threatened": true,
#     "rank_level": 10,
#     "introduced": false,
#     "native": true,
#     "parent_id": 5303,
#     "name": "Haliaeetus leucocephalus",
#     "rank": "species",
#     "extinct": false,
#     "id": 5305,
#     "ancestor_ids": [
#      48460,
#      1,
#      2,
#      355675,
#      3,
#      71261,
#      5067,
#      1542783,
#      5303,
#      5305
#     ],
#     "created_at": "2008-03-13T02:47:51+00:00",
#     "default_photo": {
#      "id": 6149726,
#      "license_code": null,
#      "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#      "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#      "original_dimensions": {
#       "height": 1133,
#       "width": 1440
#      },
#      "flags": [],
#      "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#      "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#     },
#     "taxon_changes_count": 0,
#     "taxon_schemes_count": 10,
#     "observations_count": 136386,
#     "photos_locked": false,
#     "universal_search_rank": 136386,
#     "flag_counts": {
#      "resolved": 5,
#      "unresolved": 0
#     },
#     "current_synonymous_taxon_ids": null,
#     "atlas_id": null,
#     "complete_species_count": null,
#     "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#     "complete_rank": "subspecies",
#     "iconic_taxon_name": "Aves",
#     "preferred_common_name": "Bald Eagle",
#     "conservation_status": {
#      "id": 54335,
#      "place_id": 51,
#      "source_id": 8,
#      "user_id": null,
#      "authority": "NatureServe",
#      "status": "s1b,s1n",
#      "status_name": "critically imperiled",
#      "geoprivacy": null,
#      "iucn": 50
#     }
#    },
#    "ident_taxon_ids": [
#     48460,
#     1,
#     2,
#     355675,
#     3,
#     71261,
#     5067,
#     1542783,
#     5303,
#     5305
#    ],
#    "outlinks": [],
#    "faves_count": 0,
#    "ofvs": [],
#    "num_identification_agreements": 2,
#    "preferences": {
#     "prefers_community_taxon": null
#    },
#    "comments": [],
#    "map_scale": null,
#    "uri": "https://www.inaturalist.org/observations/207206756",
#    "project_ids": [],
#    "community_taxon_id": 5305,
#    "geojson": {
#     "type": "Point",
#     "coordinates": [
#      -74.1031625,
#      40.7858645
#     ]
#    },
#    "owners_identification_from_vision": true,
#    "identifications_count": 2,
#    "obscured": false,
#    "num_identification_disagreements": 0,
#    "geoprivacy": null,
#    "location": "40.7858645,-74.1031625",
#    "votes": [],
#    "spam": false,
#    "user": {
#     "id": 4579164,
#     "login": "juan1269",
#     "spam": false,
#     "suspended": false,
#     "created_at": "2021-06-13T14:05:29+00:00",
#     "site_id": null,
#     "login_autocomplete": "juan1269",
#     "login_exact": "juan1269",
#     "name": "Juan Melli",
#     "name_autocomplete": "Juan Melli",
#     "orcid": null,
#     "icon": "https://static.inaturalist.org/attachments/users/icons/4579164/thumb.jpeg?1623593129",
#     "observations_count": 403,
#     "identifications_count": 0,
#     "journal_posts_count": 0,
#     "activity_count": 403,
#     "species_count": 240,
#     "universal_search_rank": 403,
#     "roles": [],
#     "icon_url": "https://static.inaturalist.org/attachments/users/icons/4579164/medium.jpeg?1623593129",
#     "preferences": {}
#    },
#    "mappable": true,
#    "identifications_some_agree": true,
#    "project_ids_without_curator_id": [],
#    "place_guess": "Richard W. DeKorte Park, 1 DeKorte Park, Lyndhurst, NJ 07071, USA",
#    "identifications": [
#     {
#      "id": 470757905,
#      "uuid": "f4c46472-276a-40bf-a6b2-9534b846a28f",
#      "user": {
#       "id": 4579164,
#       "login": "juan1269",
#       "spam": false,
#       "suspended": false,
#       "created_at": "2021-06-13T14:05:29+00:00",
#       "login_autocomplete": "juan1269",
#       "login_exact": "juan1269",
#       "name": "Juan Melli",
#       "name_autocomplete": "Juan Melli",
#       "orcid": null,
#       "icon": "https://static.inaturalist.org/attachments/users/icons/4579164/thumb.jpeg?1623593129",
#       "observations_count": 403,
#       "identifications_count": 0,
#       "journal_posts_count": 0,
#       "activity_count": 403,
#       "species_count": 240,
#       "universal_search_rank": 403,
#       "roles": [],
#       "site_id": null,
#       "icon_url": "https://static.inaturalist.org/attachments/users/icons/4579164/medium.jpeg?1623593129"
#      },
#      "created_at": "2024-04-14T13:09:05-04:00",
#      "created_at_details": {
#       "date": "2024-04-14",
#       "day": 14,
#       "month": 4,
#       "year": 2024,
#       "hour": 13,
#       "week": 15
#      },
#      "body": null,
#      "category": "improving",
#      "current": true,
#      "flags": [],
#      "own_observation": true,
#      "taxon_change": null,
#      "vision": true,
#      "disagreement": null,
#      "previous_observation_taxon_id": 5305,
#      "spam": false,
#      "taxon_id": 5305,
#      "hidden": false,
#      "moderator_actions": [],
#      "taxon": {
#       "id": 5305,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 3,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        3,
#        71261,
#        5067,
#        1542783,
#        5303
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 5305,
#       "name": "Haliaeetus leucocephalus",
#       "parent_id": 5303,
#       "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#       "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#       "extinct": false,
#       "created_at": "2008-03-13T02:47:51+00:00",
#       "default_photo": {
#        "id": 6149726,
#        "license_code": null,
#        "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#        "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "original_dimensions": {
#         "height": 1133,
#         "width": 1440
#        },
#        "flags": [],
#        "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 10,
#       "observations_count": 136386,
#       "photos_locked": false,
#       "universal_search_rank": 136386,
#       "flag_counts": {
#        "resolved": 5,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#       "complete_rank": "subspecies",
#       "iconic_taxon_name": "Aves",
#       "preferred_common_name": "Bald Eagle",
#       "conservation_status": {
#        "id": 54335,
#        "place_id": 51,
#        "source_id": 8,
#        "user_id": null,
#        "authority": "NatureServe",
#        "status": "s1b,s1n",
#        "status_name": "critically imperiled",
#        "geoprivacy": null,
#        "iucn": 50
#       },
#       "ancestors": [
#        {
#         "id": 1,
#         "rank": "kingdom",
#         "rank_level": 70,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1
#         ],
#         "is_active": true,
#         "name": "Animalia",
#         "parent_id": 48460,
#         "ancestry": "48460",
#         "extinct": false,
#         "default_photo": {
#          "id": 80678745,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/medium.jpg"
#         },
#         "taxon_changes_count": 8,
#         "taxon_schemes_count": 2,
#         "observations_count": 99949886,
#         "flag_counts": {
#          "resolved": 15,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Animal",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Animals"
#        },
#        {
#         "id": 2,
#         "rank": "phylum",
#         "rank_level": 60,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2
#         ],
#         "is_active": true,
#         "name": "Chordata",
#         "parent_id": 1,
#         "ancestry": "48460/1",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551845,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 40846458,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 77541,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Chordate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Chordates"
#        },
#        {
#         "id": 355675,
#         "rank": "subphylum",
#         "rank_level": 57,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675
#         ],
#         "is_active": true,
#         "name": "Vertebrata",
#         "parent_id": 2,
#         "ancestry": "48460/1/2",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551642,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 40774163,
#         "flag_counts": {
#          "resolved": 2,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 74422,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Vertebrate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Vertebrates"
#        },
#        {
#         "id": 3,
#         "rank": "class",
#         "rank_level": 50,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3
#         ],
#         "is_active": true,
#         "name": "Aves",
#         "parent_id": 355675,
#         "ancestry": "48460/1/2/355675",
#         "extinct": false,
#         "default_photo": {
#          "id": 2967053,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Greg Lasley, some rights reserved (CC BY-NC), uploaded by Greg Lasley",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/square.jpg",
#          "original_dimensions": {
#           "height": 1333,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/medium.jpg"
#         },
#         "taxon_changes_count": 4,
#         "taxon_schemes_count": 2,
#         "observations_count": 27376380,
#         "flag_counts": {
#          "resolved": 16,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 10852,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Bird",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Birds"
#        },
#        {
#         "id": 71261,
#         "rank": "order",
#         "rank_level": 40,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261
#         ],
#         "is_active": true,
#         "name": "Accipitriformes",
#         "parent_id": 3,
#         "ancestry": "48460/1/2/355675/3",
#         "extinct": false,
#         "default_photo": {
#          "id": 9972001,
#          "license_code": "cc-by",
#          "attribution": "(c) Jacob Spinks, some rights reserved (CC BY)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1500
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 1463606,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 251,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Accipitriformes",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Hawks, Eagles, Kites, and Allies"
#        },
#        {
#         "id": 5067,
#         "rank": "family",
#         "rank_level": 30,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067
#         ],
#         "is_active": true,
#         "name": "Accipitridae",
#         "parent_id": 71261,
#         "ancestry": "48460/1/2/355675/3/71261",
#         "extinct": false,
#         "default_photo": {
#          "id": 12120585,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) kjohnston406, some rights reserved (CC BY-NC), uploaded by kjohnston406",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/square.jpg",
#          "original_dimensions": {
#           "height": 1417,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 1335826,
#         "flag_counts": {
#          "resolved": 3,
#          "unresolved": 1
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 249,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Accipitridae",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Hawks, Eagles, and Kites"
#        },
#        {
#         "id": 1542783,
#         "rank": "subfamily",
#         "rank_level": 27,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067,
#          1542783
#         ],
#         "is_active": true,
#         "name": "Buteoninae",
#         "parent_id": 5067,
#         "ancestry": "48460/1/2/355675/3/71261/5067",
#         "extinct": false,
#         "default_photo": {
#          "id": 28307358,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Greg Lasley, some rights reserved (CC BY-NC), uploaded by Greg Lasley",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/square.jpg",
#          "original_dimensions": {
#           "height": 1366,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 355699,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 47,
#         "wikipedia_url": null,
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves"
#        },
#        {
#         "id": 5303,
#         "rank": "genus",
#         "rank_level": 20,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067,
#          1542783,
#          5303
#         ],
#         "is_active": true,
#         "name": "Haliaeetus",
#         "parent_id": 1542783,
#         "ancestry": "48460/1/2/355675/3/71261/5067/1542783",
#         "extinct": false,
#         "default_photo": {
#          "id": 45572716,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Carolyn Stewart, some rights reserved (CC BY-NC), uploaded by Carolyn Stewart",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/square.jpg",
#          "original_dimensions": {
#           "height": 1000,
#           "width": 1000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/medium.jpg"
#         },
#         "taxon_changes_count": 2,
#         "taxon_schemes_count": 2,
#         "observations_count": 150894,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": 96883,
#         "complete_species_count": 4,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Sea_eagle",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Northern Sea-Eagles and Fish-Eagles"
#        }
#       ]
#      },
#      "previous_observation_taxon": {
#       "id": 5305,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 3,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        3,
#        71261,
#        5067,
#        1542783,
#        5303,
#        5305
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 5305,
#       "name": "Haliaeetus leucocephalus",
#       "parent_id": 5303,
#       "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#       "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#       "extinct": false,
#       "created_at": "2008-03-13T02:47:51+00:00",
#       "default_photo": {
#        "id": 6149726,
#        "license_code": null,
#        "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#        "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "original_dimensions": {
#         "height": 1133,
#         "width": 1440
#        },
#        "flags": [],
#        "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
# ...
#      "taxon_change": null,
#      "vision": false,
#      "disagreement": false,
#      "previous_observation_taxon_id": 5305,
#      "spam": false,
#      "taxon_id": 5305,
#      "hidden": false,
#      "moderator_actions": [],
#      "taxon": {
#       "id": 5305,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 3,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        3,
#        71261,
#        5067,
#        1542783,
#        5303
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 5305,
#       "name": "Haliaeetus leucocephalus",
#       "parent_id": 5303,
#       "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#       "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#       "extinct": false,
#       "created_at": "2008-03-13T02:47:51+00:00",
#       "default_photo": {
#        "id": 6149726,
#        "license_code": null,
#        "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#        "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "original_dimensions": {
#         "height": 1133,
#         "width": 1440
#        },
#        "flags": [],
#        "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 10,
#       "observations_count": 136386,
#       "photos_locked": false,
#       "universal_search_rank": 136386,
#       "flag_counts": {
#        "resolved": 5,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#       "complete_rank": "subspecies",
#       "iconic_taxon_name": "Aves",
#       "preferred_common_name": "Bald Eagle",
#       "conservation_status": {
#        "id": 54335,
#        "place_id": 51,
#        "source_id": 8,
#        "user_id": null,
#        "authority": "NatureServe",
#        "status": "s1b,s1n",
#        "status_name": "critically imperiled",
#        "geoprivacy": null,
#        "iucn": 50
#       },
#       "ancestors": [
#        {
#         "id": 1,
#         "rank": "kingdom",
#         "rank_level": 70,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1
#         ],
#         "is_active": true,
#         "name": "Animalia",
#         "parent_id": 48460,
#         "ancestry": "48460",
#         "extinct": false,
#         "default_photo": {
#          "id": 80678745,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80678745/medium.jpg"
#         },
#         "taxon_changes_count": 8,
#         "taxon_schemes_count": 2,
#         "observations_count": 99949886,
#         "flag_counts": {
#          "resolved": 15,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": null,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Animal",
#         "complete_rank": "order",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Animals"
#        },
#        {
#         "id": 2,
#         "rank": "phylum",
#         "rank_level": 60,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2
#         ],
#         "is_active": true,
#         "name": "Chordata",
#         "parent_id": 1,
#         "ancestry": "48460/1",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551845,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551845/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 40846458,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 77541,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Chordate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Chordates"
#        },
#        {
#         "id": 355675,
#         "rank": "subphylum",
#         "rank_level": 57,
#         "iconic_taxon_id": 1,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675
#         ],
#         "is_active": true,
#         "name": "Vertebrata",
#         "parent_id": 2,
#         "ancestry": "48460/1/2",
#         "extinct": false,
#         "default_photo": {
#          "id": 80551642,
#          "license_code": "cc0",
#          "attribution": "no rights reserved, uploaded by Abhas Misraraj",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "original_dimensions": {
#           "height": 2000,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/80551642/medium.jpg"
#         },
#         "taxon_changes_count": 1,
#         "taxon_schemes_count": 1,
#         "observations_count": 40774163,
#         "flag_counts": {
#          "resolved": 2,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 74422,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Vertebrate",
#         "complete_rank": "species",
#         "iconic_taxon_name": "Animalia",
#         "preferred_common_name": "Vertebrates"
#        },
#        {
#         "id": 3,
#         "rank": "class",
#         "rank_level": 50,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3
#         ],
#         "is_active": true,
#         "name": "Aves",
#         "parent_id": 355675,
#         "ancestry": "48460/1/2/355675",
#         "extinct": false,
#         "default_photo": {
#          "id": 2967053,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Greg Lasley, some rights reserved (CC BY-NC), uploaded by Greg Lasley",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/square.jpg",
#          "original_dimensions": {
#           "height": 1333,
#           "width": 2000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/2967053/medium.jpg"
#         },
#         "taxon_changes_count": 4,
#         "taxon_schemes_count": 2,
#         "observations_count": 27376380,
#         "flag_counts": {
#          "resolved": 16,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 10852,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Bird",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Birds"
#        },
#        {
#         "id": 71261,
#         "rank": "order",
#         "rank_level": 40,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261
#         ],
#         "is_active": true,
#         "name": "Accipitriformes",
#         "parent_id": 3,
#         "ancestry": "48460/1/2/355675/3",
#         "extinct": false,
#         "default_photo": {
#          "id": 9972001,
#          "license_code": "cc-by",
#          "attribution": "(c) Jacob Spinks, some rights reserved (CC BY)",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/square.jpg",
#          "original_dimensions": {
#           "height": 1200,
#           "width": 1500
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/9972001/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 1,
#         "observations_count": 1463606,
#         "flag_counts": {
#          "resolved": 1,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 251,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Accipitriformes",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Hawks, Eagles, Kites, and Allies"
#        },
#        {
#         "id": 5067,
#         "rank": "family",
#         "rank_level": 30,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067
#         ],
#         "is_active": true,
#         "name": "Accipitridae",
#         "parent_id": 71261,
#         "ancestry": "48460/1/2/355675/3/71261",
#         "extinct": false,
#         "default_photo": {
#          "id": 12120585,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) kjohnston406, some rights reserved (CC BY-NC), uploaded by kjohnston406",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/square.jpg",
#          "original_dimensions": {
#           "height": 1417,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/12120585/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 2,
#         "observations_count": 1335826,
#         "flag_counts": {
#          "resolved": 3,
#          "unresolved": 1
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 249,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Accipitridae",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Hawks, Eagles, and Kites"
#        },
#        {
#         "id": 1542783,
#         "rank": "subfamily",
#         "rank_level": 27,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067,
#          1542783
#         ],
#         "is_active": true,
#         "name": "Buteoninae",
#         "parent_id": 5067,
#         "ancestry": "48460/1/2/355675/3/71261/5067",
#         "extinct": false,
#         "default_photo": {
#          "id": 28307358,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Greg Lasley, some rights reserved (CC BY-NC), uploaded by Greg Lasley",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/square.jpg",
#          "original_dimensions": {
#           "height": 1366,
#           "width": 2048
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/28307358/medium.jpg"
#         },
#         "taxon_changes_count": 0,
#         "taxon_schemes_count": 0,
#         "observations_count": 355699,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": null,
#         "complete_species_count": 47,
#         "wikipedia_url": null,
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves"
#        },
#        {
#         "id": 5303,
#         "rank": "genus",
#         "rank_level": 20,
#         "iconic_taxon_id": 3,
#         "ancestor_ids": [
#          48460,
#          1,
#          2,
#          355675,
#          3,
#          71261,
#          5067,
#          1542783,
#          5303
#         ],
#         "is_active": true,
#         "name": "Haliaeetus",
#         "parent_id": 1542783,
#         "ancestry": "48460/1/2/355675/3/71261/5067/1542783",
#         "extinct": false,
#         "default_photo": {
#          "id": 45572716,
#          "license_code": "cc-by-nc",
#          "attribution": "(c) Carolyn Stewart, some rights reserved (CC BY-NC), uploaded by Carolyn Stewart",
#          "url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/square.jpg",
#          "original_dimensions": {
#           "height": 1000,
#           "width": 1000
#          },
#          "flags": [],
#          "square_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/square.jpg",
#          "medium_url": "https://inaturalist-open-data.s3.amazonaws.com/photos/45572716/medium.jpg"
#         },
#         "taxon_changes_count": 2,
#         "taxon_schemes_count": 2,
#         "observations_count": 150894,
#         "flag_counts": {
#          "resolved": 0,
#          "unresolved": 0
#         },
#         "current_synonymous_taxon_ids": null,
#         "atlas_id": 96883,
#         "complete_species_count": 4,
#         "wikipedia_url": "http://en.wikipedia.org/wiki/Sea_eagle",
#         "complete_rank": "subspecies",
#         "iconic_taxon_name": "Aves",
#         "preferred_common_name": "Northern Sea-Eagles and Fish-Eagles"
#        }
#       ]
#      },
#      "previous_observation_taxon": {
#       "id": 5305,
#       "rank": "species",
#       "rank_level": 10,
#       "iconic_taxon_id": 3,
#       "ancestor_ids": [
#        48460,
#        1,
#        2,
#        355675,
#        3,
#        71261,
#        5067,
#        1542783,
#        5303,
#        5305
#       ],
#       "is_active": true,
#       "min_species_taxon_id": 5305,
#       "name": "Haliaeetus leucocephalus",
#       "parent_id": 5303,
#       "ancestry": "48460/1/2/355675/3/71261/5067/1542783/5303",
#       "min_species_ancestry": "48460,1,2,355675,3,71261,5067,1542783,5303,5305",
#       "extinct": false,
#       "created_at": "2008-03-13T02:47:51+00:00",
#       "default_photo": {
#        "id": 6149726,
#        "license_code": null,
#        "attribution": "(c) Bryan Pfeiffer, all rights reserved, uploaded by Bryan Pfeiffer",
#        "url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "original_dimensions": {
#         "height": 1133,
#         "width": 1440
#        },
#        "flags": [],
#        "square_url": "https://static.inaturalist.org/photos/6149726/square.jpg",
#        "medium_url": "https://static.inaturalist.org/photos/6149726/medium.jpg"
#       },
#       "taxon_changes_count": 0,
#       "taxon_schemes_count": 10,
#       "observations_count": 136386,
#       "photos_locked": false,
#       "universal_search_rank": 136386,
#       "flag_counts": {
#        "resolved": 5,
#        "unresolved": 0
#       },
#       "current_synonymous_taxon_ids": null,
#       "atlas_id": null,
#       "complete_species_count": null,
#       "wikipedia_url": "http://en.wikipedia.org/wiki/Bald_eagle",
#       "complete_rank": "subspecies",
#       "iconic_taxon_name": "Aves",
#       "preferred_common_name": "Bald Eagle",
#       "conservation_status": {
#        "id": 54335,
#        "place_id": 51,
#        "source_id": 8,
#        "user_id": null,
#        "authority": "NatureServe",
#        "status": "s1b,s1n",
#        "status_name": "critically imperiled",
#        "geoprivacy": null,
#        "iucn": 50
#       }
#      }
#     }
#    ]
#   }
#  ]
# }

# %% [markdown]
# You can continue to explore your new API connection created from scratch, or continue to Part 2 steps below:
